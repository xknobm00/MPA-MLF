# %% [markdown]
# <a href="https://colab.research.google.com/github/xknobm00/MPA-MLF/blob/main/CV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MKA-MLF, Lab_08 - RNN

# %% [markdown]
# Recurrent Neural Networks, are a class of artificial neural networks designed to recognize patterns in sequences of data, such as text, genomes, handwriting, or spoken words. Unlike traditional neural networks, which assume all inputs (and outputs) are independent of each other, RNNs are designed to recognize sequential or temporal patterns, making them especially suited for tasks like language modeling, speech recognition, and time series prediction.

# %% [markdown]
# ## Exercise 1 - Time Series Forecasting

# %% [markdown]
# ### 1.0 Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense, Flatten, SimpleRNN
from keras.models import Sequential
from keras.optimizers import Adam

# %% [markdown]
# ### 1.1 Generating dataset

# %%
def generate_time_series(batch_size, n_steps):
  freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
  time = np.linspace(0,1,n_steps)

  series = 0.5 * np.sin((time - offsets1) * (freq1*10 + 10))
  series += 0.2 * np.sin((time - offsets2) * (freq2*20 + 20))
  series += 0.1 * (np.random.rand(batch_size, n_steps)- 0.5)
  return series[..., np.newaxis].astype(np.float32)

# %%
data_size = 10000
n_steps = 50
np.random.seed(0)

series = generate_time_series(data_size, n_steps + 1)

# %% [markdown]
# ### 1.2 Train/Valid/Test split

# %%
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
no_training_epochs = 5

# %% [markdown]
# ### 1.3 Data examination

# %%
plt.figure()
plt.plot(X_train[0])
plt.plot(n_steps+1, y_train[0], 'rx')

# %% [markdown]
# ### 1.4 Simple Linear model

# %%
# Model definition
model_linear = Sequential()
model_linear.add(Flatten(input_shape=(50,1)))
model_linear.add(Dense(1, activation = None))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Model building

learning_rate = 0.001
optimizer = Adam(learning_rate)
model_linear.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_squared_error'])

# %%
model_linear.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 51 (204.00 B)
#  Trainable params: 51 (204.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model training

history_linear = model_linear.fit(X_train, y_train, epochs=no_training_epochs, validation_data=[X_valid, y_valid])
# Out:
# Epoch 1/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1277 - mean_squared_error: 0.1277 - val_loss: 0.0338 - val_mean_squared_error: 0.0338
# Epoch 2/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 3/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 4/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 5/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0078 - val_mean_squared_error: 0.0078

# %%
def plot_function(history):
  plt.figure()

  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='validation_loss')
  plt.legend()
  plt.grid()
  plt.xlim([0,no_training_epochs-1])
  plt.xlabel('epochs')

# %%
plot_function(history_linear)

# %%
score = model_linear.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print(f'Test MSE: ', score[1])
# Out:
# Test loss: 0.007596774958074093
# Test MSE:  0.007596774958074093

# %% [markdown]
# ### 1.5 Simple RNN Model

# %%
model_simple_rnn = Sequential()
model_simple_rnn.add(SimpleRNN(1, input_shape=[50, 1]))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
learning_rate_simple_rnn = 0.001
optimizer_simple_rnn = Adam(learning_rate_simple_rnn)
model_simple_rnn.compile(loss='mean_squared_error', optimizer=optimizer_simple_rnn, metrics=['mean_squared_error'])

# %%
history_simple_rnn = model_simple_rnn.fit(X_train, y_train, epochs=no_training_epochs, validation_data=[X_valid, y_valid])
# Out:
# Epoch 1/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.3540 - mean_squared_error: 0.3540 - val_loss: 0.3190 - val_mean_squared_error: 0.3190
# Epoch 2/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3093 - mean_squared_error: 0.3093 - val_loss: 0.2762 - val_mean_squared_error: 0.2762
# Epoch 3/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2607 - mean_squared_error: 0.2607 - val_loss: 0.2367 - val_mean_squared_error: 0.2367
# Epoch 4/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2267 - mean_squared_error: 0.2267 - val_loss: 0.2003 - val_mean_squared_error: 0.2003
# Epoch 5/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1941 - mean_squared_error: 0.1941 - val_loss: 0.1703 - val_mean_squared_error: 0.1703

# %%
plot_function(history_simple_rnn)

# %% [markdown]
# ### 1.5 Deep RNN Model

# %%
model_deep_rnn = Sequential()
model_deep_rnn.add(SimpleRNN(20, return_sequences = True, input_shape=[50, 1]))
model_deep_rnn.add(SimpleRNN(20, return_sequences = True))
model_deep_rnn.add(SimpleRNN(1, input_shape=[50, 1]))

# %%
learning_rate_deep_rnn = 0.001
optimizer_deep_rnn = Adam(learning_rate_deep_rnn)
model_deep_rnn.compile(loss='mean_squared_error', optimizer=optimizer_deep_rnn, metrics=['mean_squared_error'])

# %%
history_deep_rnn = model_deep_rnn.fit(X_train, y_train, epochs=no_training_epochs, validation_data=[X_valid, y_valid])
# Out:
# Epoch 1/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 2/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 3/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 4/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 5/5
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_mean_squared_error: 0.0032

# %%
score = model_deep_rnn.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print(f'Test MSE: ', score[1])
# Out:
# Test loss: 0.003448289353400469
# Test MSE:  0.003448289353400469

# %%
plot_function(history_simple_rnn)

# %% [markdown]
# ## Exercise 2 - The movie review

# %% [markdown]
# Based on the written rewiev, classify if the movie if good or bad

# %% [markdown]
# ### 2.0 - Import libraries

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras) (4.13.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, SimpleRNN, GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import imdb
import torch.nn as nn

# %% [markdown]
# ### 2.1 - Load dataset

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data()

# %% [markdown]
# ### 2.2 - Dataset examination

# %%
word_index = keras.datasets.imdb.get_word_index()
id_to_word = {id_ + 3:word for word, id_ in word_index.items()}
for id_, token in enumerate(("<pad>", "<sos>", "<unk>")):
  id_to_word[id_] = token

# %%
single_sequence = " ".join([id_to_word[id_] for id_ in X_train[0][:]])

# %%
single_sequence
# Out:
# "<sos> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert redford's is an amazing actor and now the same being director norman's father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for retail and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also congratulations to the two little boy's that played the part's of norman and paul they were just brilliant children are often left out of the praising list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
max_length = 150  # Define the maximum length of a review
X_train = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_length, padding='post', truncating='post', value=0)
X_test = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_length, padding='post', truncating='post', value=0)

# %%
embed_size = 128
vocabulary_size = 1000

# LSTM Model
lstm_model = Sequential([
    Embedding(vocabulary_size, embed_size, input_shape=[None]),
    LSTM(128, return_sequences=True),
    LSTM(128),
    Dense(1, activation='sigmoid')
])


# GRU Model
gru_model = Sequential([
    Embedding(vocabulary_size, embed_size, input_shape=[None]),
    GRU(128, return_sequences=True),
    GRU(128),
    Dense(1, activation='sigmoid')
])


# SimpleRNN Model (for comparison)
simple_rnn_model = Sequential([
    Embedding(vocabulary_size, embed_size, input_shape=[None]),
    SimpleRNN(128, return_sequences=True),
    SimpleRNN(128),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
optimizer = Adam(learning_rate = 0.001)

# %%
lstm_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=["accuracy"])
gru_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=["accuracy"])
simple_rnn_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
simple_rnn_history = simple_rnn_model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_test, y_test), verbose=2)

lstm_history = lstm_model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_test, y_test), verbose=2)

gru_history = gru_model.fit(X_train, y_train, epochs=5, batch_size=128, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/5
# 196/196 - 7s - 34ms/step - accuracy: 0.5894 - loss: 0.6580 - val_accuracy: 0.5066 - val_loss: 0.7248
# Epoch 2/5
# 196/196 - 10s - 51ms/step - accuracy: 0.6258 - loss: 0.6239 - val_accuracy: 0.5106 - val_loss: 0.7442
# Epoch 3/5
# 196/196 - 7s - 37ms/step - accuracy: 0.6534 - loss: 0.5964 - val_accuracy: 0.4978 - val_loss: 0.7955
# Epoch 4/5
# 196/196 - 7s - 37ms/step - accuracy: 0.6788 - loss: 0.5664 - val_accuracy: 0.4964 - val_loss: 0.8376
# Epoch 5/5
# 196/196 - 10s - 53ms/step - accuracy: 0.7009 - loss: 0.5341 - val_accuracy: 0.4965 - val_loss: 0.8631
# Epoch 1/5
# 196/196 - 7s - 37ms/step - accuracy: 0.8243 - loss: 0.3903 - val_accuracy: 0.8214 - val_loss: 0.3934
# Epoch 2/5
# 196/196 - 10s - 52ms/step - accuracy: 0.8366 - loss: 0.3708 - val_accuracy: 0.8285 - val_loss: 0.3815
# Epoch 3/5
# 196/196 - 9s - 48ms/step - accuracy: 0.8401 - loss: 0.3611 - val_accuracy: 0.8293 - val_loss: 0.3738
# Epoch 4/5
# 196/196 - 10s - 52ms/step - accuracy: 0.8492 - loss: 0.3467 - val_accuracy: 0.8325 - val_loss: 0.3771
# Epoch 5/5
# 196/196 - 11s - 56ms/step - accuracy: 0.8527 - loss: 0.3359 - val_accuracy: 0.8340 - val_loss: 0.3669
# Epoch 1/5
# 196/196 - 6s - 30ms/step - accuracy: 0.8306 - loss: 0.3776 - val_accuracy: 0.8192 - val_loss: 0.4033
# Epoch 2/5
# 196/196 - 6s - 29ms/step - accuracy: 0.8402 - loss: 0.3619 - val_accuracy: 0.8262 - val_loss: 0.3795
# Epoch 3/5
# 196/196 - 6s - 30ms/step - accuracy: 0.8480 - loss: 0.3477 - val_accuracy: 0.8288 - val_loss: 0.3763
# Epoch 4/5
# 196/196 - 11s - 56ms/step - accuracy: 0.8554 - loss: 0.3342 - val_accuracy: 0.8292 - val_loss: 0.3794
# Epoch 5/5
# 196/196 - 9s - 48ms/step - accuracy: 0.8616 - loss: 0.3213 - val_accuracy: 0.8303 - val_loss: 0.3745

# %%
simple_rnn_score = simple_rnn_model.evaluate(X_test, y_test, verbose=0)
print("SimpleRNN Test loss:", simple_rnn_score[0])
print("SimpleRNN Test accuracy:", simple_rnn_score[1] * 100, "%")
plot_function(simple_rnn_history)
plt.title('SimpleRNN Model Loss')
# Out:
# SimpleRNN Test loss: 0.8631118535995483
# SimpleRNN Test accuracy: 49.65200126171112 %
# Text(0.5, 1.0, 'SimpleRNN Model Loss')

# %%
gru_score = gru_model.evaluate(X_test, y_test, verbose=0)
print("GRU Test loss:", gru_score[0])
print("GRU Test accuracy:", gru_score[1] * 100, "%")
plot_function(gru_history)
plt.title('GRU Model Loss')
# Out:
# GRU Test loss: 0.37451648712158203
# GRU Test accuracy: 83.02800059318542 %
# Text(0.5, 1.0, 'GRU Model Loss')

# %%
lstm_score = lstm_model.evaluate(X_test, y_test, verbose=0)
print("LSTM Test loss:", lstm_score[0])
print("LSTM Test accuracy:", lstm_score[1] * 100, "%")
plot_function(lstm_history)
plt.title('LSTM Model Loss')
# Out:
# LSTM Test loss: 0.3669203817844391
# LSTM Test accuracy: 83.39599967002869 %
# Text(0.5, 1.0, 'LSTM Model Loss')

# %% [markdown]
# TASK: Modify structure, change the core of the network from RNN to LTSM and GRU. Compare the results

# %% [markdown]
# The results showed that both LSTM and GRU outperformed the basic RNN in terms of accuracy, with GRU being slightly faster while maintaining similar performance.
